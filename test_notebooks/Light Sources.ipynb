# %% [markdown]
# # Light sources

# %%
# A point source

import torchlensmaker as tlm
import torch.nn as nn
import torch

shape = tlm.Parabola(width = 10., a = 0.04)
lens = tlm.SymmetricLens(shape, (1.0, 1.5), outer_thickness=1.0)

optics = nn.Sequential(
    tlm.PointSource(height=0, beam_angle=25),
    tlm.Gap(20),
    lens,
    tlm.Gap(25),
    tlm.FocalPointLoss(),
)

tlm.render_plt(optics)

# %%
# Multiple point sources

import torchlensmaker as tlm
import torch.nn as nn
import torch

shape = tlm.Parabola(width = 10., a = 0.04)
lens = tlm.SymmetricLens(shape, (1.0, 1.5), outer_thickness=1.0)

optics = nn.Sequential(
    tlm.PointSource(height=0, beam_angle=25),
    tlm.PointSource(height=1, beam_angle=25),
    tlm.PointSource(height=2, beam_angle=25),
    tlm.Gap(20),
    lens,
    tlm.Gap(25),
    tlm.FocalPointLoss(),
)

tlm.render_plt(optics)

# %%
# A point source at infinity

import torchlensmaker as tlm
import torch.nn as nn
import torch

shape = tlm.Parabola(width = 10., a = 0.03)
lens = tlm.SymmetricLens(shape, (1.0, 1.5), outer_thickness=1.0)

optics = nn.Sequential(
    tlm.PointSourceAtInfinity(angle=5., beam_diameter=10),
    tlm.Gap(5),
    lens,
    tlm.Gap(15),
    tlm.FocalPointLoss(),
)

tlm.render_plt(optics)
# Out:
# rays aperture 8.711111
# rays aperture 0.0
# rays aperture 8.708495
# rays aperture 8.46686

# %%
# Multiple point sources at infinity

import torchlensmaker as tlm
import torch.nn as nn
import torch

shape = tlm.Parabola(width = 10., a = 0.03)
lens = tlm.SymmetricLens(shape, (1.0, 1.5), outer_thickness=1.0)

optics = nn.Sequential(
    tlm.PointSourceAtInfinity(angle=5, beam_diameter=10),
    tlm.PointSourceAtInfinity(angle=0, beam_diameter=10),
    tlm.PointSourceAtInfinity(angle=-5, beam_diameter=10),
    tlm.Gap(5),
    lens,
    tlm.Gap(15),
    tlm.FocalPointLoss(),
)

tlm.render_plt(optics)
# Out:
# rays aperture 9.8
# rays aperture 9.8
# rays aperture 9.8
# rays aperture 9.588334

# %%
# TODO make this correctly render

import torchlensmaker as tlm
import torch.nn as nn
import torch

optics = nn.Sequential(
    tlm.PointSource(height=0, beam_angle=25),
)

tlm.render_plt(optics)
